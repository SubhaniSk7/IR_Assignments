# %%
# Some .sav files are from 1st question. So, First run First.ipynb and run this file.

# %%
import nltk
import pandas as pd
import os,re,math,glob

from collections import Counter
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize,RegexpTokenizer,TweetTokenizer
from nltk.stem.porter import PorterStemmer
from nltk import wordpunct_tokenize
from nltk.stem import WordNetLemmatizer

import pandas as pd
import re as regex
import numpy as np
import scipy
from sklearn.externals import joblib
import contractions

# %%
# from my previous assignment
def contract(text):
    return contractions.fix(text)

def regTokenize(text):
    tok=RegexpTokenizer('[A-Za-z0-9]*[.]?\w+')
    return tok.tokenize(text) 

def lowercase(text):
    return text.lower()

def lemma(words):
    for i in range(0,len(words)):
        words[i]=WordNetLemmatizer().lemmatize(words[i])
    return words

def stemming(words):
    porter_stemmer=PorterStemmer()
    for i in range(0,len(words)):
        words[i]=porter_stemmer.stem(words[i])
    return words

def tweet(words):
    tok=TweetTokenizer()
    return tok.tokenize(words)

def comma(text):
    text = "".join(c for c in text if c not in ('!','.',':',',','"','?','(',')'))
    return text

# %%
document_ids=joblib.load('document_ids.sav')
metadata=joblib.load('metadata.sav')
title_dictionary=joblib.load('title_dictionary.sav')
body_dictionary=joblib.load('body_dictionary.sav')
for i in metadata:
    print(i,'\n')
    break
for key,value in title_dictionary.items():
    print(key,value,'\n')
    break
for key,value in body_dictionary.items():
    print(key, value)
    break
# Out:
# ['stories/100west.txt', 'Going 100 West by 53 North by Jim Prentice (1990)', 3101]
#
# stories/100west.txt ['go', '100', 'west', 'by', '53', 'north', 'by', 'jim', 'prentic', '(', '1990', ')']
#
# cackl [13, ['stories/100west.txt', 'stories/assorted.txt', 'stories/bookem.1', 'stories/breaks3.asc', 'stories/candle.hum', 'stories/chik', 'stories/cybersla.txt', 'stories/eyeargon.hum', 'stories/foxngrap.txt', 'stories/fred.txt', 'stories/paink-ws.txt', 'stories/piracy.sto', 'stories/rocket.sf']]

# %%
words=body_dictionary.keys()
print(len(words))
words=list(words)
# print(words)
# Out:
# 34830
# ['cackl', 'medic', 'per', 'surveyor', 'against', 'threateningli', 'loon', 'seldom', 'should', 'bass', 'snell', 'send', 'job', 'such', 'engin', 'wa', 'clear', 'shovel', 'oil', 'expens', 'poet', 'catfish', 'offer', 'burbot', 'all', 'kept', 'landscap', 'read', 'element', 'rough', 'fast', 'never', 'open', 'round', 'turn', 'expect', 'smog', 'entrepreneur', 'diminish', 'bay', '100', 'remov', 'wild', 'may', 'visual', 'sold', 'these', 'batteri', 'legion', 'pond', 'black', 'cabin', 'stop', 'oper', 'requir', 'week', 'hous', 'refuel', 'intern', 'hum', 'branch', 'product', '1984', 'north', 'allow', 'through', 'tie', 'provid', 'sport', 'balki', 'then', 'howl', 'raven', 'transmiss', 'alway', 'bull', 'into', 'too', 'reserv', 'yet', 'rope', 'bait', 'patrol', 'lore', 'can', 'in', 'major', 'newspap', 'cover', 'trip', 'low', 'windflow', 'tire', 'copyright', 'ground', 'to', 'summer', 'tow', 'what', 'recent', 'trout', 'willow', 'februari', 'wonder', 'good', 'play', 'problem', 'moos', 'tullibe', 'weekend', 'usual', 'prior', 'bo', 'huddl', 'countri', 'thi', 'chore', '2', 'around', 'freez', 'motorhom', 'friend', 'pilot', 'hook', 'mower', 'lawn', 'abound', 'tourist', 'is', 'after', 'sucker', 'standard', 'scene', 'by', 'privat', 'sometim', 'set', 'diesel', 'mumbl', 'mani', '1990', 'brush', 'store', 'bolt', 'govern', 'civil', 'pipelin', 'one', 'schedul', 'avail', 'threaten', 'here', 'return', 'shop', 'remot', 'snowmachin', 'area', 'avga', 'incred', 'urban', 'gourmet', 'that', 'situat', 'afford', 'haul', 'blueberri', 'pancak', 'sound', 'look', 'give', 'spoken', 'know', 'useless', 'whi', 'music', 'auger', 'live', 'becom', 'carri', 'weather', 'rifl', 'censu', 'year', 'taxi', 'thought', 'campground', 'anoth', 'telephon', 'giant', 'effici', 'face', 'star', 'heavi', 'interv', 'commerci', 'aircraft', 'meet', 'acut', 'stranger', 'settlement', 'annual', 'ever', 'seclud', 'but', 'passeng', 'white', 'been', 'custom', 'entomologist', 'toy', 'highway', 'awar', 'midsumm', 'struck', 'facil', 'role', 'cessna', 'brandon', 'place', 'opportun', 'babi', 'thick', 'camaraderi', 'contribut', 'if', 'also', 'bu', 'ran', 'record', 'involv', 'check', 'are', 'trapper', 'resid', 'contact', 'jim', 'includ', 'dure', 'local', 'river', 'dock', 'made', 'sharewar', 'colder', 'employ', 'skidoo', 'undisturb', 'lift', 'charter', 'twig', 'for', 'authent', 'hi', 'exampl', 'pass', 'evergreen', 'nativ', 'tear', 'condit', 'chin', 'airstrip', 'dweller', 'present', 'reflect', 'sign', 'month', 'prime', 'navig', 'deliv', 'transact', 'rake', 'appar', 'while', 'color', 'somehow', 'plane', 'well', 'kind', 'fume', 'territori', 'moosemeat', 'radio', 'ventur', 'difficult', 'crystal', 'prentic', 'whiteout', 'buzz', 'center', 'favorit', 'chanc', 'beaver', 'merchant', 'howev', 'repair', 'fare', 'trap', 'ill', 'morn', 'circl', 'wildlif', 'electr', 'beauti', 'leav', 'lump', 'shack', 'hand', 'surround', 'permit', 'far', 'drill', 'theater', 'lower', 'consider', 'colleagu', 'lure', 'shore', 'catch', 'independ', 'writer', 'boat', 'nation', 'would', 'serious', 'medevac', 'egg', 'accustom', 'stock', 'the', 'day', 'happen', 'strip', 'wheel', 'stuck', 'spring', 'traffic', 'flew', 'aid', 'altitud', 'degre', 'most', 'stream', 'wear', 'gener', 'placid', 'it', 'preheat', 'everi', 'raspberri', 'ear', 'extend', 'unnerv', 'car', 'zero', 'get', 'abl', 'prepar', 'quantiti', 'start', 'doe', 'announc', 'kid', 'or', 's', 'a', 'bundl', 'differ', 'were', 'death', 'special', 'occasion', 'some', 'system', 'super', 'so', 'fli', 'time', 'trial', 'recreat', 'herald', 'realiti', 'decid', 'maximum', 'power', 'trailer', 'lone', 'fisherman', 'eat', 'deep', 'adjust', 'whether', 'ride', 'hour', 'normal', 'lead', 'hydro', '214', 'teem', 'laundri', 'our', 'snowmobil', 'perch', 'timer', 'night', 'forest', 'indic', 'head', 'reced', 'which', 'call', 'wind', 'endur', '10000', 'shown', 'nonexist', 'pin', 'produc', 'lack', 'side', 'surfac', 'appli', 'exist', 'spoon', 'home', 'could', 'rival', 'label', 'keep', 'cours', 'they', 'out', '10', 'adapt', 'h ...

# %%
def getDocLength(docId):
    for i in metadata:
        if(i[0]==docId):
            return i[2]

def getWordFreqInBodyDoc(docId,word):
    f=open(docId,'r+',errors='ignore')
    data=f.read()
    data=lowercase(data)
    data=contract(data)
    data=comma(data)
#     data=tweet(data)
    data=regTokenize(data)
    data=lemma(data)
    data=stemming(data)
    
    freq=data.count(word)
    return freq

def getWordFreqinTitle(docId, word):
    return title_dictionary.get(docId).count(word)

def getQPosts(term):
    return body_dictionary.get(term)[1]

def getDocWords(docId):
    f=open(docId,'r+',errors='ignore')
    data=f.read()
    data=lowercase(data)
    data=contract(data)
    data=comma(data)
    data=regTokenize(data)
    data=lemma(data)
    data=stemming(data)
    
    return data

def getTitleWords(docId):
    return title_dictionary.get(docId)

# %% [markdown]
# ### construction vector

# %%
vsm=[]

title_weight=0.6
body_weight=0.4
n=len(document_ids)

for i in document_ids:
    print(i)
    
    d_tf_idf=[]
    total=0
    
    doc_words=getDocWords(i)
    title_words=getTitleWords(i)
    for w in words:
#         print(w)
        
#         bodyFreq=getWordFreqInBodyDoc(i,w)
        bodyFreq=doc_words.count(w)
#         titleFreq=getWordFreqinTitle(i,w)
        titleFreq=title_words.count(w)
        
        if(bodyFreq>0 and titleFreq>0):
            weight=1
        elif(bodyFreq>0 and titleFreq==0):
            weight=0.4
        else:
            weight=0.6
        
        freq=bodyFreq
        tf=freq/getDocLength(i)
        
        inner=n/body_dictionary.get(j)[0]
        idf=math.log(inner)
        
        tf_idf=tf*idf*weight
        
        d_tf_idf.append(tf_idf)
    vsm.append(d_tf_idf)
# Out:
# stories/100west.txt
# stories/13chil.txt
# stories/14.lws
# stories/16.lws
# stories/17.lws
# stories/18.lws
# stories/19.lws
# stories/20.lws
# stories/3gables.txt
# stories/3lpigs.txt
# stories/3sonnets.vrs
# stories/3student.txt
# stories/3wishes.txt
# stories/4moons.txt
# stories/5orange.txt
# stories/6ablemen.txt
# stories/6napolen.txt
# stories/7oldsamr.txt
# stories/7voysinb.txt
# stories/ab40thv.txt
# stories/abbey.txt
# stories/abyss.txt
# stories/adler.txt
# stories/adv_alad.txt
# stories/advsayed.txt
# stories/advtthum.txt
# stories/aesop11.txt
# stories/aesopa10.txt
# stories/aircon.txt
# stories/aisle.six
# stories/aislesix.txt
# stories/alad10.txt
# stories/alissadl.txt
# stories/altside.hum
# stories/aluminum.hum
# stories/aminegg.txt
# stories/angelfur.hum
# stories/angry_ca.txt
# stories/antcrick.txt
# stories/aquith.txt
# stories/arcadia.sty
# stories/archive
# stories/arctic.txt
# stories/asop
# stories/assorted.txt
# stories/bagel.man
# stories/bagelman.txt
# stories/batlslau.txt
# stories/beast.asc
# stories/beautbst.txt
# stories/beggars.txt
# stories/bern
# stories/berternie.txt
# stories/bestwish
# stories/beyond.hum
# stories/bgb.txt
# stories/bgcspoof.txt
# stories/bigred.hum
# stories/bishop00.txt
# stories/blabnove.hum
# stories/blabnove.txt
# stories/blackp.txt
# stories/blackrdr
# stories/blak
# stories/blasters.fic
# stories/blh.txt
# stories/blind.txt
# stories/blossom.pom
# stories/blue
# stories/bluebrd.txt
# stories/bookem.1
# stories/bookem2
# stories/bookem3
# stories/brain.damage
# stories/bram
# stories/bran
# stories/breaks1.asc
# stories/breaks2.asc
# stories/breaks3.asc
# stories/bruce-p.txt
# stories/buggy.txt
# stories/buldetal.txt
# stories/buldream.txt
# stories/bulfelis.txt
# stories/bulhuntr.txt
# stories/bulironb.txt
# stories/bullove.txt
# stories/bulmrx.txt
# stories/bulnland.txt
# stories/bulnoopt.txt
# stories/bulolli1.txt
# stories/bulolli2.txt
# stories/bulphrek.txt
# stories/bulprint.txt
# stories/bulwer.lytton
# stories/bulzork1.txt
# stories/bumm
# stories/bureau.txt
# stories/burintrv.66
# stories/burintrv.78
# stories/burintrv.92
# stories/burltrs
# stories/burn
# stories/cabin.txt
# stories/cameloto.hum
# stories/campfire.txt
# stories/candle.hum
# stories/cardcnt.txt
# stories/ccm.txt
# stories/charlie.txt
# stories/chik
# stories/clevdonk.txt
# stories/clon
# stories/cmoutmou.txt
# stories/comp
# stories/confilct.fun
# stories/consumdr.hum
# stories/contrad1.hum
# stories/cooldark.sto
# stories/cooldark.txt
# stories/corcor.hum
# stories/cow.exploder
# stories/crabhern.txt
# stories/crazy.hum
# stories/cum
# stories/curious.george
# stories/cybersla.txt
# stories/dakota.txt
# stories/dan
# stories/darkness.txt
# stories/day.in.mcdonald
# stories/deal
# stories/deathmrs.d
# stories/deer.txt
# stories/descent.poe
# stories/diaryflf.txt
# stories/dicegame.txt
# stories/dicksong.txt
# stories/disco.be.fun
# stories/discocanbefun.txt
# stories/domain.poe
# stories/dopedenn.txt
# stories/dskool.txt
# stories/dtruck.txt
# stories/dwar
# stories/elite.app
# stories/elveshoe.txt
# stories/emperor3.txt
# stories/empnclot.txt
# stories/empsjowk.txt
# stories/empty.txt
# stories/enc
# stories/encamp01.txt
# stories/enchdup.hum
# stories/enginer.txt
# stories/enya_trn.txt
# stories/excerpt.hum
# stories/excerpt.txt
# stories/eyeargon.hum
# stories/ezoff
# stories/fable.txt
# stories/fantas.hum
# stories/fantasy.hum
# stories/fantasy.txt
# stories/fea1
# stories/fea2
# stories/fea3
# stories/fear.hum
# stories/fearmnky
# stories/fgoose.txt
# stories/fic1
# stories/fic2
# stories/fic3
# stories/fic4
# stories/fic5
# stories/fic7
# stories/fish.txt
# stories/fleas.txt
# stories/flktrp.txt
# stories/floc
# stories/floobs.txt
# stories/flute.txt
# stories/flytrunk.txt
# stories/forgotte
# stories/fourth.fic
# stories/fowl.death
# stories/foxncrow.txt
# stories/foxngrap.txt
# stories/foxnstrk.txt
# stories/fran
# stories/fred.txt
# stories/freeman.fil
# stories/friend.s
# stories/friends.txt
# stories/frogp.txt
# stories/frum
# stories/game.txt
# stories/gatherng.txt
# stories/gay
# stories/gemdra.txt
# stories/ghost
# stories/girl
# stories/girlclub.txt
# stories/glimpse1.txt
# stories/gloves.txt
# stories/gold3ber.txt
# stories/goldbug.poe
# stories/goldenp.txt
# stories/goldfish.txt
# stories/goldgoos.txt
# stories/grav
# stories/graymare.txt
# stories/greatlrn.leg
# stories/greedog.txt
# stories/gulliver.txt
# stories/hansgrtl.txt
# stories/hareleph.txt
# stories/hareporc.txt
# stories/haretort.txt
# stories/healer.txt
# stories/hell4.txt
# stories/hellmach.txt
# stories/helmfuse.txt
# stories/hils
# stories/history5.txt
# stories/hitch2.txt
# stories/hitch3.txt
# stories/hole2nar.txt
# stories/holmesbk.txt
# stories/home.fil
# stories/hop-frog.poe
# stories/horsdonk.txt
# stories/horswolf.txt
# stories/hotline1.txt
# stories/hotline3.txt
# stories/hotline4.txt
# stories/hound-b.txt
# stories/how.ernie.bert
# stories/idi.hum
# stories/igiv
# stories/imagin.hum
# stories/immortal
# stories/immorti.hum
# stories/imonly17.txt
# stories/inter
# stories/island.poe
# stories/jackbstl.txt
# stories/jackmac.fic
# stories/jaynejob.asc
# stories/jerichms.hum
# stories/jim.asc
# stories/keeping.insanit
# stories/keepmodu.txt
# stories/kharian.txt
# stories/kneeslapper
# stories/kneeslapper.txt
# stories/knuckle.txt
# stories/korea.s
# stories/kzap.txt
# stories/ladylust.hum
# stories/lament.txt
# stories/lgoldbrd.txt
# stories/life.txt
# stories/lil
# stories/lionbird
# stories/lionmane.txt
# stories/lionmosq.txt
# stories/lionwar.txt
# stories/lmermaid.txt
# stories/lmtchgrl.txt
# stories/long1-3.txt
# stories/lpeargrl.txt
# stories/lrrhood.txt
# stories/ltp
# stories/luf
# stories/lure.txt
# stories/mario.txt
# stories/mattress.txt
# stories/mazarin.txt
# stories/mcdonaldl.txt
# stories/melissa.txt
# stories/mike.txt
# stories/mindprob.txt
# stories/mindwar
# stories/missing.txt
# stories/modemhippy.txt
# stories/monkking.txt
# stories/monksol.txt
# stories/mouslion.txt
# stories/mtinder.txt
# stories/musgrave.txt
# stories/musibrem.txt
# stories/mydream.txt
# stories/myeyes
# stories/narciss.txt
# stories/nigel.1
# stories/nigel.10
# stories/nigel.2
# stories/nigel.3
# stories/nigel.4
# stories/nigel.5
# stories/nigel.6
# stories/nigel.7
# stories/nihgel_8.9
# stories/nitepeek.sto
# stories/non2
# stories/non3
# stories/non4
# stories/obstgoat.txt
# stories/omarsheh.txt
# stories/outcast.dos
# stories/oxfrog.txt
# stories/paink-ws.txt
# stories/panama.txt
# stories/parotsha.txt
# stories/partya.txt
# stories/paul_har.sto
# stories/peace.fun
# stories/pepdegener.txt
# stories/pepsi.degenerat
# stories/perf
# stories/pinocch.txt
# stories/piracy.sto
# stories/plescopm.txt
# stories/poem-1.txt
# stories/poem-2.txt
# stories/poem-4.txt
# stories/poplstrm.txt
# stories/pphamlin.txt
# stories/pregn.txt
# stories/prince.art
# stories/progx
# stories/psf.txt
# stories/psi
# stories/psyc
# stories/pussboot.txt
# stories/qcarroll
# stories/quarter.c1
# stories/quarter.c10
# stories/quarter.c11
# stories/quarter.c12
# stories/quarter.c13
# stories/quarter.c14
# stories/quarter.c15
# stories/quarter.c16
# stories/quarter.c17
# stories/quarter.c18
# stories/quarter.c19
# stories/quarter.c2
# stories/quarter.c3
# stories/quarter.c4
# stories/quarter.c5
# stories/quarter.c6
# stories/quarter.c7
# stories/quarter.c8
# stories/quarter.c9
# stories/quest
# stories/quickfix
# stories/quot
# stories/radar_ra.txt
# stories/rainda.txt
# stories/reality.txt
# stories/reap
# stories/redragon.txt
# stories/retrib.txt
# stories/rid.txt
# stories/robotech
# stories/rock
# stories/rocket.sf
# stories/roger1.txt
# stories/running.txt
# stories/s&m_plot
# stories/s&m_that
# stories/safe
# stories/sanpedr2.txt
# stories/shoscomb.txt
# stories/shrdfarm.txt
# stories/shulk.txt
# stories/sick-kid.txt
# stories/sight.txt
# stories/silverb.txt
# stories/sis
# stories/sleprncs.txt
# stories/snow.txt
# stories/snowmaid.txt
# stories/snowqn1.txt
# stories/social.vikings
# stories/socialvikings.txt
# stories/solitary.txt
# stories/space.txt
# stories/spam.key
# stories/spectacl.poe
# stories/spider.txt
# stories/spiders.txt
# stories/sqzply.txt
# stories/sre-dark.txt
# stories/stainles.ana
# stories/stairdre.txt
# stories/startrek.txt
# stories/stsgreek
# stories/sucker.txt
# stories/sunday.txt
# stories/superg1
# stories/szechuan
# stories/t_zone.jok
# stories/tailbear.txt
# stories/tao3.dos
# stories/taxnovel.txt
# stories/tcoa.txt
# stories/tctac.txt
# stories/tearglas.txt
# stories/telefone.txt
# stories/terrorbears.txt
# stories/testpilo.hum
# stories/textfile.primer
# stories/thanksg
# stories/the-tree.txt
# stories/thewave
# stories/timem.hac
# stories/times.fic
# stories/timetrav.txt
# stories/tin
# stories/tinsoldr.txt
# stories/toilet.s
# stories/traitor.txt
# stories/tree.txt
# stories/tuc_mees
# stories/uglyduck.txt
# stories/unluckwr.txt
# stories/vaincrow.txt
# stories/vainsong.txt
# stories/valen
# stories/vampword.txt
# stories/vday.hum
# stories/veiledl.txt
# stories/vgilante.txt
# stories/wall.art
# stories/wanderer.fun
# stories/weaver.txt
# stories/weeprncs.txt
# stories/whgdsreg.reg
# stories/wisteria.txt
# stories/withdraw.cyb
# stories/wlgirl.txt
# stories/wolf7kid.txt
# stories/wolfcran.txt
# stories/wolflamb.txt
# stories/wombat.und
# stories/write
# stories/wrt
# stories/yukon.txt
# stories/zombies.txt
# stories/SRE/sre01.txt
# stories/SRE/sre02.txt
# stories/SRE/sre03.txt
# stories/SRE/sre04.txt
# stories/SRE/sre05.txt
# stories/SRE/sre06.txt
# stories/SRE/sre07.txt
# stories/SRE/sre08.txt
# stories/SRE/sre09.txt
# stories/SRE/sre10.txt
# stories/SRE/sre_feqh.txt
# stories/SRE/sre_finl.txt
# stories/SRE/sre_sei.txt
# stories/SRE/sretrade.txt
# stories/SRE/srex.txt

# %%
words=list(words)
# Out:
# 33704
# 89
# 689

# %% [markdown]
# ### saving(dumping)

# %%
vsm_fname='vsm.sav'
joblib.dump(vsm,vsm_fname)
# Out:
# ['vsm.sav']

# %% [markdown]
# ### pre-processing for testing

# %%
def pre_processing_test(term):
    term=lowercase(term)
    term=contract(term)
    term=comma(term)
    term=regTokenize(term)
    term=lemma(term)
    term=stemming(term)
    return term

# %% [markdown]
# ### Input

# %%
query=input('enter query:')
k=int(input('enter k:'))
print(query,' ', k)
q_terms=pre_processing_test(query)
print(q_terms)

q_posts=[]
for i in q_terms:
    if(i in body_dictionary.keys()):
        posts=getQPosts(i)
    else:
        print(i,' not in dictionary.')
        posts=[]
    q_posts.append(posts)
# Out:
# enter query:trip trip
# enter k:5
# trip trip   5
# ['trip', 'trip']

# %% [markdown]
# ### constructing query terms vector

# %%
# q_vector=[0 for i in range(len(words))]

# for w in range(len(words)):
#     word=words[w]
#     if(word in q_terms):
#         tf=q_terms.count(word)
#     else:
#         tf=0
#     q_vector[w]=tf

def getQVector(q_terms):
    q_vsm=[0 for i in range(len(words))]
    for w in range(len(words)):
        word=words[w]
        if(word in q_terms):
            tf=q_terms.count(word)
        else:
            tf=0
        q_vsm[w]=tf
    return q_vsm

# %%
q_vector=getQVector(q_terms)

# %% [markdown]
# ### getting postings

# %%
total_postings=set.intersection(*map(set,q_posts))
total_postings=list(total_postings)
print(len(total_postings))
# Out:
# 101

# %% [markdown]
# ### calculating cosine similarity with documents and storing

# %%
import numpy as np

cosine_values=[]
for i in range(len(document_ids)):
    cosine_values.append([document_ids[i],0])
    
for i in total_postings:
    index=document_ids.index(i)
    print(document_ids[index],'-' ,index)
    
    dot_prod=np.dot(vsm[index],q_vector)
    a=np.linalg.norm(vsm[index],ord=2)
    b=np.linalg.norm(q_vector,ord=2)
#     print(a,b,(a*b),dot_prod/(a*b))
    
    numerator=dot_prod
    denominator=a*b
    sim=numerator/denominator
    cosine_values[index]=[document_ids[index],sim]
# Out:
# stories/kzap.txt - 258
# stories/elite.app - 145
# stories/floc - 179
# stories/breaks3.asc - 78
# stories/mindprob.txt - 282
# stories/fic5 - 174
# stories/ghost - 200
# stories/perf - 320
# stories/robotech - 366
# stories/taxnovel.txt - 407
# stories/7voysinb.txt - 18
# stories/hitch2.txt - 225
# stories/nihgel_8.9 - 303
# stories/corcor.hum - 120
# stories/cybersla.txt - 126
# stories/curious.george - 125
# stories/nigel.10 - 296
# stories/buldetal.txt - 81
# stories/gay - 198
# stories/quarter.c10 - 338
# stories/running.txt - 370
# stories/hitch3.txt - 226
# stories/100west.txt - 0
# stories/fic2 - 171
# stories/psi - 333
# stories/idi.hum - 238
# stories/dan - 128
# stories/cooldark.txt - 119
# stories/nigel.3 - 298
# stories/bishop00.txt - 58
# stories/snow.txt - 383
# stories/arctic.txt - 42
# stories/bulironb.txt - 85
# stories/long1-3.txt - 270
# stories/chik - 110
# stories/radar_ra.txt - 359
# stories/forgotte - 183
# stories/roger1.txt - 369
# stories/burintrv.66 - 98
# stories/solitary.txt - 388
# stories/igiv - 239
# stories/aluminum.hum - 34
# stories/fic7 - 175
# stories/archive - 41
# stories/bulprint.txt - 93
# stories/fantasy.txt - 163
# stories/sick-kid.txt - 378
# stories/vday.hum - 433
# stories/quest - 356
# stories/outcast.dos - 310
# stories/rocket.sf - 368
# stories/hellmach.txt - 221
# stories/beast.asc - 48
# stories/goldgoos.txt - 209
# stories/quarter.c17 - 345
# stories/knuckle.txt - 256
# stories/fantasy.hum - 162
# stories/cooldark.sto - 118
# stories/blabnove.hum - 59
# stories/burintrv.92 - 100
# stories/gulliver.txt - 214
# stories/charlie.txt - 109
# stories/SRE/sre05.txt - 456
# stories/immortal - 241
# stories/space.txt - 389
# stories/blabnove.txt - 60
# stories/fran - 189
# stories/angelfur.hum - 36
# stories/vgilante.txt - 435
# stories/game.txt - 196
# stories/girlclub.txt - 202
# stories/quarter.c15 - 343
# stories/plescopm.txt - 323
# stories/stainles.ana - 396
# stories/crazy.hum - 123
# stories/history5.txt - 224
# stories/breaks2.asc - 77
# stories/darkness.txt - 129
# stories/grav - 210
# stories/tearglas.txt - 410
# stories/sight.txt - 379
# stories/6ablemen.txt - 15
# stories/crabhern.txt - 122
# stories/superg1 - 402
# stories/sqzply.txt - 394
# stories/bulhuntr.txt - 84
# stories/yukon.txt - 450
# stories/bgb.txt - 55
# stories/blind.txt - 66
# stories/sis - 381
# stories/burintrv.78 - 99
# stories/dakota.txt - 127
# stories/cmoutmou.txt - 113
# stories/batlslau.txt - 47
# stories/dskool.txt - 142
# stories/fic1 - 170
# stories/bureau.txt - 97
# stories/bulmrx.txt - 87
# stories/diaryflf.txt - 135
# stories/fgoose.txt - 169
# stories/blak - 63

# %%
# print(cosine_values[258])

# %% [markdown]
# ### sorting the list

# %%
from operator import itemgetter
sorted_scores = sorted(cosine_values, key=itemgetter(1),reverse=True)

# %%
# for i in sorted_scores:
#     print(i)

# %% [markdown]
# ### printing top K docs

# %%
flag=False
if(k<=len(sorted_scores)):
    for i in range(k):
        print(sorted_scores[i])
        flag=True
else:
    for i in sorted_scores:
        print(i)
        flag=True

if(not flag):
    print('No Documents are matched.')
# Out:
# ['stories/quarter.c15', 0.026766783225108566]
# ['stories/blind.txt', 0.014784021489596169]
# ['stories/100west.txt', 0.014004009081421345]
# ['stories/space.txt', 0.013499653653953855]
# ['stories/burintrv.66', 0.013473436988288593]
